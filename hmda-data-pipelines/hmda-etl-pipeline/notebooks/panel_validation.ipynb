# %%
import pandas as pd 

etl = pd.read_csv("/Users/bienstocke/Documents/Github/kedro-etl-pipeline/hmda-etl-pipeline/data/2022/institutions/02_data_publication/2023-08-29-2022_panel.txt", header=None, sep="|",
                  na_filter=False)
etl.shape
# Out:
# (4466, 18)

# %%
leg = pd.read_csv("/Users/bienstocke/Desktop/2023-08-26-2022_panel.txt", header=None, sep="|", na_filter=False)
leg.shape
# Out:
# (4466, 18)

# %%
leg.head()
# Out:
#                      0     1   2   3        4           5        6   \
# 0  5493009YXZEN8325UC34  2022   7  14           46-3986756  4877394
# 1  B4TYDEB6GKMZO031MB27  2022   9   1   480228  94-1687665   480228
# 2  5493000YNV8IX4VD3X12  2022   7  14  1936928  62-0997810  1936928
# 3  549300VZVN841I2ILS84  2022   7  14  4183602  57-1175755  4183602
# 4  549300CB67L6KPJLHE19  2022   7  14  4320902  59-1515932  4320902
#
#                                                   7   \
# 0                               stearns.com,rate.com
# 1  bankofamerica.com,bankofamerica.com,bofa.com,b...
# 2  claytonhomes.com,vmf.com, claytonhomes.com,VMF...
# 3                                   myccmortgage.com
# 4                                        triadfs.com
#
#                                       8   9             10       11  \
# 0            HOME MORTGAGE ALLIANCE, LLC                         -1
# 1  Bank of America, National Association  NC     Charlotte  1379552
# ...

# %%
etl.head()
# Out:
#                      0     1   2   3        4           5        6   \
# 0  5493009YXZEN8325UC34  2022   7  14           46-3986756  4877394
# 1  B4TYDEB6GKMZO031MB27  2022   9   1   480228  94-1687665   480228
# 2  5493000YNV8IX4VD3X12  2022   7  14  1936928  62-0997810  1936928
# 3  549300VZVN841I2ILS84  2022   7  14  4183602  57-1175755  4183602
# 4  549300CB67L6KPJLHE19  2022   7  14  4320902  59-1515932  4320902
#
#                                                   7   \
# 0                              stearns.com, rate.com
# 1  bankofamerica.com, bankofamerica.com, bofa.com...
# 2  claytonhomes.com, vmf.com, claytonhomes.com, V...
# 3                                   myccmortgage.com
# 4                                        triadfs.com
#
#                                       8   9             10       11  \
# 0            HOME MORTGAGE ALLIANCE, LLC                         -1
# 1  Bank of America, National Association  NC     Charlotte  1379552
# ...
